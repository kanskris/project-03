# %%
import numpy as np 
import pandas as pd 
import json
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot
from pandas import datetime
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_json (r'SIRI.json')
size = len(df)

df2 = pd.DataFrame([[0,0,0,0,"ok", 1586221417, 0]], columns=list('chlostv'))
df = df.append(df2, ignore_index=True)
df['t'] = pd.to_datetime(df['t'], unit='s')

# %%
df
# Out:
#         c     h     l     o   s                   t         v
# 0    5.41  5.44  5.38  5.41  ok 2017-07-12 13:30:00  17006500
# 1    5.43  5.47  5.39  5.39  ok 2017-07-13 13:30:00  17455600
# 2    5.48  5.48  5.43  5.46  ok 2017-07-14 13:30:00  13135200
# 3    5.46  5.48  5.45  5.46  ok 2017-07-17 13:30:00  10163600
# 4    5.41  5.47  5.39  5.45  ok 2017-07-18 13:30:00  18020000
# ..    ...   ...   ...   ...  ..                 ...       ...
# 685  4.64  4.91  4.60  4.76  ok 2020-04-01 13:30:00  26473100
# 686  4.75  4.85  4.51  4.59  ok 2020-04-02 13:30:00  23163200
# 687  4.48  4.76  4.41  4.73  ok 2020-04-03 13:30:00  20780700
# 688  4.79  4.85  4.68  4.72  ok 2020-04-06 00:00:00  24039700
# 689  0.00  0.00  0.00  0.00  ok 2020-04-07 01:03:37         0
#
# [690 rows x 7 columns]

# %%
train_data, test_data = df[0:int(len(df)*0.8)], df[int(len(df)*0.8):]
plt.figure(figsize=(12,7))
plt.title('Sirus XM Prices')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.plot(train_data['c'], 'blue', label='Training Data')
plt.plot(test_data['c'], 'green', label='Testing Data')
plt.xticks(np.arange(0,size, 300), df['t'][0:size:300])
plt.legend()

# %%
def smape_kun(y_true, y_pred):
    return np.mean((np.abs(y_pred - y_true) * 200/ (np.abs(y_pred) +       np.abs(y_true))))
train_ar = train_data['c'].values
date = test_data['t'].values
test_ar = test_data['c'].values
history = [x for x in train_ar]
print(type(history))
predictions = list()
for t in range(len(test_ar)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_ar[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test_ar, predictions)
print('Testing Mean Squared Error: %.3f' % error)
error2 = smape_kun(test_ar, predictions)
print('Symmetric mean absolute percentage error: %.3f' % error2)
# Out:
# <class 'list'>
# predicted=6.344082, expected=6.260000
# predicted=6.264769, expected=6.290000
# predicted=6.289782, expected=6.230000
# predicted=6.234217, expected=6.320000
# predicted=6.316955, expected=6.260000
# predicted=6.265276, expected=6.210000
# predicted=6.213573, expected=6.260000
# predicted=6.258667, expected=6.180000
# predicted=6.185814, expected=6.230000
# predicted=6.228408, expected=6.350000
# predicted=6.345620, expected=6.380000
# predicted=6.381473, expected=6.330000
# predicted=6.334571, expected=6.240000
# predicted=6.245461, expected=6.250000
# predicted=6.250806, expected=6.250000
# predicted=6.251701, expected=6.310000
# predicted=6.308918, expected=6.330000
# predicted=6.330801, expected=6.440000
# predicted=6.436773, expected=6.430000
# predicted=6.432773, expected=6.480000
# predicted=6.479416, expected=6.430000
# predicted=6.434291, expected=6.420000
# predicted=6.421858, expected=6.400000
# predicted=6.402628, expected=6.450000
# predicted=6.449445, expected=6.460000
# predicted=6.461901, expected=6.440000
# predicted=6.442856, expected=6.460000
# predicted=6.460674, expected=6.370000
# predicted=6.376191, expected=6.470000
# predicted=6.466287, expected=6.720000
# predicted=6.711389, expected=6.820000
# predicted=6.819829, expected=6.770000
# predicted=6.773185, expected=6.830000
# predicted=6.829043, expected=6.780000
# predicted=6.783935, expected=6.800000
# predicted=6.801335, expected=6.850000
# predicted=6.850402, expected=6.960000
# predicted=6.958500, expected=6.930000
# predicted=6.934203, expected=6.880000
# predicted=6.883911, expected=6.980000
# predicted=6.978201, expected=6.920000
# predicted=6.925581, expected=6.950000
# predicted=4.514926, expected=4.790000
# predicted=4.726091, expected=0.000000
# Testing Mean Squared Error: 0.186
# Symmetric mean absolute percentage error: 13.096

# %%
date
# Out:
# array(['2019-09-20T13:30:00.000000000', '2019-09-23T13:30:00.000000000',
#        '2019-09-24T13:30:00.000000000', '2019-09-25T13:30:00.000000000',
#        '2019-09-26T13:30:00.000000000', '2019-09-27T13:30:00.000000000',
#        '2019-09-30T13:30:00.000000000', '2019-10-01T13:30:00.000000000',
#        '2019-10-02T13:30:00.000000000', '2019-10-03T13:30:00.000000000',
#        '2019-10-04T13:30:00.000000000', '2019-10-07T13:30:00.000000000',
#        '2019-10-08T13:30:00.000000000', '2019-10-09T13:30:00.000000000',
#        '2019-10-10T13:30:00.000000000', '2019-10-11T13:30:00.000000000',
#        '2019-10-14T13:30:00.000000000', '2019-10-15T13:30:00.000000000',
#        '2019-10-16T13:30:00.000000000', '2019-10-17T13:30:00.000000000',
#        '2019-10-18T13:30:00.000000000', '2019-10-21T13:30:00.000000000',
#        '2019-10-22T13:30:00.000000000', '2019-10-23T13:30:00.000000000',
#        '2019-10-24T13:30:00.000000000', '2019-10-25T13:30:00.000000000',
#        '2019-10-28T13:30:00.000000000', '2019-10-29T13:30:00.000000000',
#        '2019-10-30T13:30:00.000000000', '2019-10-31T13:30:00.000000000',
#        '2019-11-01T13:30:00.000000000', '2019-11-04T14:30:00.000000000',
#        '2019-11-05T14:30:00.000000000', '2019-11-06T14:30:00.000000000',
#        '2019-11-07T14:30:00.000000000', '2019-11-08T14:30:00.000000000',
#        '2019-11-11T14:30:00.000000000', '2019-11-12T14:30:00.000000000',
#        '2019-11-13T14:30:00.000000000', '2019-11-14T14:30:00.000000000',
#        '2019-11-15T14:30:00.000000000', '2019-11-18T14:30:00.000000000',
#        '2019-11-19T14:30:00.000000000', '2019-11-20T14:30:00.000000000',
#        '2019-11-21T14:30:00.000000000', '2019-11-22T14:30:00.000000000',
#        '2019-11-25T14:30:00.000000000', '2019-11-26T14:30:00.000000000',
#        '2019-11-27T14:30:00.000000000', '2019-11-29T14:30:00.000000000',
#        '2019-12-02T14:30:00.000000000', '2019-12-03T14:30:00.000000000',
#        '2019-12-04T14:30:00.000000000', '2019-12-05T14:30:00.000000000',
#        '2019-12-06T14:30:00.000000000', '2019-12-09T14:30:00.000000000',
#        '2019-12-10T14:30:00.000000000', '2019-12-11T14:30:00.000000000',
#        '2019-12-12T14:30:00.000000000', '2019-12-13T14:30:00.000000000',
#        '2019-12-16T14:30:00.000000000', '2019-12-17T14:30:00.000000000',
#        '2019-12-18T14:30:00.000000000', '2019-12-19T14:30:00.000000000',
#        '2019-12-20T14:30:00.000000000', '2019-12-23T14:30:00.000000000',
#        '2019-12-24T14:30:00.000000000', '2019-12-26T14:30:00.000000000',
#        '2019-12-27T14:30:00.000000000', '2019-12-30T14:30:00.000000000',
#        '2019-12-31T14:30:00.000000000', '2020-01-02T14:30:00.000000000',
#        '2020-01-03T14:30:00.000000000', '2020-01-06T14:30:00.000000000',
#        '2020-01-07T14:30:00.000000000', '2020-01-08T14:30:00.000000000',
#        '2020-01-09T14:30:00.000000000', '2020-01-10T14:30:00.000000000',
#        '2020-01-13T14:30:00.000000000', '2020-01-14T14:30:00.000000000',
#        '2020-01-15T14:30:00.000000000', '2020-01-16T14:30:00.000000000',
#        '2020-01-17T14:30:00.000000000', '2020-01-21T14:30:00.000000000',
#        '2020-01-22T14:30:00.000000000', '2020-01-23T14:30:00.000000000',
#        '2020-01-24T14:30:00.000000000', '2020-01-27T14:30:00.000000000',
#        '2020-01-28T14:30:00.000000000', '2020-01-29T14:30:00.000000000',
#        '2020-01-30T14:30:00.000000000', '2020-01-31T14:30:00.000000000',
#        '2020-02-03T14:30:00.000000000', '2020-02-04T14:30:00.000000000',
#        '2020-02-05T14:30:00.000000000', '2020-02-06T14:30:00.000000000',
#        '2020-02-07T14:30:00.000000000', '2020-02-10T14:30:00.000000000',
#        '2020-02-11T14:30:00.000000000', '2020-02-12T14:30:00.000000000',
#        '2020-02-13T14:30:00.000000000', '2020-02-14T14:30:00.000000000',
#        '2020-02-18T14:30:00.000000000', '2020-02-19T14:30:00.000000000',
#        '2020-02-20T14:30:00.000000000', '2020-02-21T14:30:00.000000000',
#        '2020-02-24T14:30:00.000000000', '2020-02-25T14:30:00.000000000',
#        '2020-02-26T14:30:00.000000000', '2020-02-27T14:30:00.000000000',
#        '2020-02-28T14:30:00.000000000', '2020-03-02T14:30:00.000000000',
#        '2020-03-03T14:30:00.000000000', '2020-03-04T14:30:00.000000000',
#        '2020-03-05T14:30:00.000000000', '2020-03-06T14:30:00.000000000',
#        '2020-03-09T13:30:00.000000000', '2020-03-10T13:30:00.000000000',
#        '2020-03-11T13:30:00.000000000', '2020-03-12T13:30:00.000000000',
#        '2020-03-13T13:30:00.000000000', '2020-03-16T13:30:00.000000000',
#        '2020-03-17T13:30:00.000000000', '2020-03-18T13:30:00.000000000',
#        '2020-03-19T13:30:00.000000000', '2020-03-20T13:30:00.000000000',
#        '2020-03-23T13:30:00.000000000', '2020-03-24T13:30:00.000000000',
#        '2020-03-25T13:30:00.000000000', '2020-03-26T13:30:00.000000000',
#        '2020-03-27T13:30:00.000000000', '2020-03-30T13:30:00.000000000',
#        '2020-03-31T13:30:00.000000000', '2020-04-01T13:30:00.000000000',
#        '2020-04-02T13:30:00.000000000', '2020-04-03T13:30:00.000000000',
#        '2020-04-06T00:00:00.000000000', '2020-04-07T01:03:37.000000000'],
#       dtype='datetime64[ns]')

# %%
predict = pd.DataFrame({"Predictions": predictions, "Actual" : test_ar, "Date": date})
predict.to_json(r'APD(SIRI).json')

# %%
predict
# Out:
#               Predictions  Actual                Date
# 0     [6.344082135664579]    6.26 2019-09-20 13:30:00
# 1     [6.264769180832997]    6.29 2019-09-23 13:30:00
# 2    [6.2897816270432605]    6.23 2019-09-24 13:30:00
# 3     [6.234217385728018]    6.32 2019-09-25 13:30:00
# 4     [6.316955128022448]    6.26 2019-09-26 13:30:00
# ..                    ...     ...                 ...
# 133   [4.904936235118939]    4.64 2020-04-01 13:30:00
# 134   [4.711059397749585]    4.75 2020-04-02 13:30:00
# 135   [4.690825283262637]    4.48 2020-04-03 13:30:00
# 136    [4.51492555277847]    4.79 2020-04-06 00:00:00
# 137   [4.726090922960578]    0.00 2020-04-07 01:03:37
#
# [138 rows x 3 columns]

# %%
plt.plot(test_ar)
plt.plot(predictions, color='red')
plt.show()

# %%
plt.figure(figsize=(12,7))
#plt.plot(df['c'], 'green', color='blue', label='Training Data')
plt.plot(test_data.index, predictions, color='green', marker='o', linestyle='dashed', 
         label='Predicted Price')
plt.plot(test_data.index, test_data['c'], color='red', marker='x', label='Actual Price')
plt.title('Sirus XM Prices Prediction')
plt.xlabel('Dates')
plt.ylabel('Prices')
plt.xticks(np.arange(0,size, 1300), df['t'][0:size:1300])
plt.legend()
